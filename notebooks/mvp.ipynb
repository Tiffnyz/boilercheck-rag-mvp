# %%
import json
import os
from dotenv import load_dotenv

load_dotenv()

with open("../data/rag_mock_data.json") as f:
    docs = json.load(f)

print("Loaded sections:", len(docs))
docs[0]
# Out:
# Loaded sections: 2
# {'document_id': 'housing_policy_2025',
#  'title': 'University Residences Guidelines and Policies',
#  'domain': 'housing',
#  'url': 'https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html',
#  'effective_date': '2025-12-15',
#  'sections': [{'section_title': 'Emergency Procedures',
#    'subsections': [{'section_title': 'Accidents',
#      'text': 'Contact the nearest staff member or the main office for assistance. Staff will arrange ambulance transportation and other needed help. Dial 9-1-1 from any campus telephone for immediate contact with the Purdue Police.'},
#     {'section_title': 'Bomb Threats',
#      'text': 'An intermittent signal on the fire alarm system indicates a bomb threat has been received. If the signal becomes continuous, the building must be totally evacuated.'},
#     {'section_title': 'Fire or Explosion',
#      'text': 'Activate the nearest fire alarm to cause evacuation of the building. Report location of the fire if possible.'},
#     {'section_title': 'Tornado Warning',
#      'text': 'Activation of a continuous siren indicates that a tornado may be in the immediate vicinity. You should immediately seek cover and proceed to the lower areas away from windows.'},
#     {'section_title': 'Unauthorized Group Action',
#      'text': 'Close and lock your windows, close the draperies, and stay away from window areas. Refrain from calling out windows or throwing items out. Such actions only call attention to you and may result in damage to your room and neighboring rooms, or risk personal injury from broken glass.'},
#     {'section_title': 'Utilities Failure',
#      'text': 'Notify your staff member or the main office. In more widespread failures, further instructions will be provided by University Residences staff.'}]},
#   {'section_title': 'Safety',
#    'subsections': [{'section_title': 'General Information',
#      'text': 'The University Residences management team considers the safety and security of residents a top priority. Everyone must help maintain the safety and security of the residences. To report an incident, visit the Office of Student Rights and Responsibilities.'},
#     {'section_title': 'In the Residences',
#      'text': 'Actions that jeopardize the safety of other residents include: consumption of alcohol or illicit drugs, possession of a weapon, discharging fire extinguishers when there is no fire, propping doors open that should be closed or locked, removing screens from windows, or any form of vandalism. These actions will result in judicial proceedings.'},
#     {'section_title': 'Access Clerk',
#      'text': 'Each residence hall is equipped with a card reader access device that will unlock the exterior door after hours. Residents will use their Purdue Identification card to swipe the door access device card reader to unlock the exterior door of their assigned hall (excludes Hilltop Apartments). A night access clerk is stationed at the main office of each residence hall to monitor residents and their escorted guests who enter the building after hours.'},
#     {'section_title': 'Confront Strangers',
#      'text': 'Ask unescorted strangers why they are in the residence. If you feel uncomfortable doing this, ask an RA or another staff member to intervene. If you feel there is an immediate threat, call 911.'},
#     {'section_title': 'Identify Personal Items',
#      'text': 'Mark your personal items and keep an inventory of your property.'},
#     {'section_title': 'Items Prohibited',
#      'text': 'Items prohibited from University Residences buildings and grounds due to safety or fire hazard concerns include but are not limited to: electric/battery or gasoline motorized cycles, scooters, hoverboards or similar equipment; electric blankets or electric bed warmers of any kind; grow lights; halogen lamps; soldering tools; sun lamps; paintball guns; portable heating units; portable air conditioning units (student-furnished air conditioners are permitted in Hilltop Apartments); extension cords, power strips and charging devices that do not bear the seal of an independent testing laboratory accredited by the CPSC; and 3D Printers. Prohibited appliance use in traditional residential rooms includes: air fryers, bread makers, convection ovens, crockpots, electric grills, electric mixers, electric blenders, electric skillets/griddles, fryers/deep fryers, panini/press grills, pressure cookers, pressing irons, steam/rice cookers, and toasters/toaster ovens.'},
#     {'section_title': 'Keep Your Key/PUID',
#      'text': 'Never lend your key or PUID out to anyone. Doing so is a conduct policy violation. Lock your room anytime you leave and while sleeping. Visit your hall office if you lose your key or ID to obtain loaners and hear options about replacements.'},
#     {'section_title': 'Lock Doors',
#      'text': 'Locking your door is the easiest and most effective way to prevent unwanted visitors from entering your room. Do not prop open locked outside doors that allow entrance into the building.'},
#     {'section_title': 'Report Safety-Related Maintenance Problems',
#      'text': 'Please report all security and safety-related problems directly to Resident Assistants, Facilities staff, or the main office. Examples include broken windows, faulty doors, lock problems, missing screens, and fire safety equipment. Work orders can be submitted via the Fix My Home online site, but work orders are only monitored during business hours.'},
#     {'section_title': 'Report Crimes Immediately',
#      'text': 'If you are the victim of any crime or witness one in progress, report this to the Purdue University Police Department immediately. You should also report all criminal activity to a Residential Life staff member so that they can take action to protect the welfare and property of other residents.'},
#     {'section_title': 'Reporting Sexual Crimes',
#      'text': 'Victims of sexual assault or other sexual crimes can receive assistance by contacting the Purdue University Police Department. For confidential assistance, a person may visit Counseling & Psychological Services (CAPS) or Center for Advocacy, Response & Education (CARE). Individuals may also get assistance in reporting options, remedial measures and support services through the Office of Institutional Equity.'},
#     {'section_title': 'Reporting Sexual Harassment',
#      'text': 'To learn about Sexual Harassment, individuals can review university definitions, reporting options, and individuals who can be contacted for additional information.'},
#     {'section_title': 'Secure Parked Cars',
#      'text': 'Lock your doors and roll up your windows when parking your car. Keep valuables, especially book bags, laptops, airpods, and other electronic equipment out of sight.'},
#     {'section_title': 'Stay Alert',
#      'text': "Campus safety and security are everyone's responsibility. Your fellow residents depend on you to help keep their home safe. If you have any questions about safety and security, contact your RA, residence management, club officers, or the Purdue University Police Department (PUPD)."},
#     {'section_title': 'Walking on Campus',
#      'text': 'When walking on or off campus at night, go with a friend. If you cannot walk with a friend, the Purdue Student Security Patrol provides security escorts upon request on Thursday, Friday, and Saturday nights. To request an escort, call 49-4SAFE (494-7233). Emergency Telephone System (ETS) boxes painted bright yellow and illuminated with a blue light are located across campus for emergencies.'}]},
#   {'section_title': 'Student Conduct Policies',
#    'subsections': [{'section_title': 'Alcohol',
#      'text': 'Students are prohibited from consuming, transporting, and distributing alcohol; possessing or being in the presence of alcohol; or exhibiting disruptive behavior influenced by the use of alcohol. Alcohol found by staff will be disposed of immediately. Violations may result in warning/reprimand, parental contact, referral to an alcohol education program (up to $260 fee), termination of housing contract, university probated suspension or expulsion, and/or possible arrest. No empty alcohol containers may be displayed at any time or in any location.'},
#     {'section_title': 'Drugs',
#      'text': 'All illegal drugs as defined by Indiana state law and any type of recreational drugs are strictly prohibited from University Residences facilities and property. This includes marijuana, hashish, hash oil, cocaine, crack, LSD, inhalants, stimulants, depressants, hallucinogens, narcotics, designer drugs, anabolic steroids and other substances that alter mental state. Students are also prohibited from possessing paraphernalia with evidence of illegal drug use. Anyone found in violation may have their housing contract terminated and may be subject to University disciplinary action and possible arrest.'},
#     {'section_title': 'Weapons',
#      'text': 'Weapons are strictly prohibited from University Residences facilities and property. Prohibited weapons include: handguns, rifles, shotguns, BB guns, pellet guns, dart guns, bows and arrows, swords, martial arts implements and explosives whether manufactured or handmade, including live ammunition. Anyone found in violation will have their housing contract terminated and may be subject to University disciplinary action and possible arrest.'},
#     {'section_title': 'Candles and Incense',
#      'text': 'The use and/or storage of candles and incense are not permitted in the Residences due to fire, injury, and property damage risks.'},
#     {'section_title': 'Door/Window Decorating',
#      'text': 'Only Door Decs are allowed on residence hall/apartment doors, limited to 2 per occupant. No items may be affixed or block the windows for fire safety purposes. Items can be placed on the sill. Doors cannot be wrapped in paper or other material. Posters and bulletin boards are not permitted on doors. Community fliers are allowed on designated bulletin boards or posting areas in building hallways.'},
#     {'section_title': 'Corridors',
#      'text': 'Games, sports, and unauthorized group activity are not permitted in hallways. Residents may not use the corridors to store excess items from rooms.'},
#     {'section_title': 'Courtesy Hours',
#      'text': "Residents are expected to always demonstrate consideration and courtesy toward others and, if asked, are expected to have a prompt and positive response to another resident's request to stop disruptive behavior."},
#     {'section_title': 'Dishonesty',
#      'text': 'Dishonesty such as knowingly furnishing false information, cheating or plagiarism is prohibited.'},
#     {'section_title': 'Disruptive Behavior',
#      'text': 'Residents are prohibited from obstruction or disruption of University-related activity or inciting, aiding or encouraging other persons to engage in such conduct. This also includes any conduct that substantially threatens or interferes with the maintenance of appropriate order and discipline, or activity that invades the rights of others.'},
#     {'section_title': 'Emergency Procedures',
#      'text': 'Residents are expected to follow the prescribed University Residences emergency procedures or the directions of a staff member in case of accidents, bomb threat, fire or explosion, tornado warning, unauthorized group action or utilities failure.'},
#     {'section_title': 'Escort Guests',
#      'text': 'Any person that does not live in the residence hall they are visiting must be escorted by a resident of that hall at all times. Residents are responsible for the behavior of their guests and can be held accountable for the actions of their guests.'},
#     {'section_title': 'Fire Alarms/Equipment',
#      'text': 'Misuse of the fire alarm system, including sounding a false alarm or tampering with extinguishers or smoke detectors, is prohibited.'},
#     {'section_title': 'Fireworks',
#      'text': 'All fireworks are prohibited from University Residences buildings and grounds.'},
#     {'section_title': 'Forgery',
#      'text': 'Residents are prohibited from unauthorized use or alteration of University documents, records or identification.'},
#     {'section_title': 'Gambling',
#      'text': 'Gambling is prohibited under Indiana Legislative Code. A person who knowingly or intentionally engages in gambling commits unlawful gambling, a Class B misdemeanor. Use of the Internet to engage in unlawful gambling in Indiana is a Class D felony.'},
#     {'section_title': "Guests' Behavior",
#      'text': "Residents will be held responsible for their guests' behavior and conformity with all University and University Residences policies. Guests who obstruct or disrupt the orderly function of the residence facilities may be asked to leave the building by authorized staff."},
#     {'section_title': 'Guest Hours',
#      'text': 'Aspire Apartments, First Street Towers, Frieda and Winifred Parker, Hawkins, Hillenbrand, Hilltop Apartments, and UR Boiler Apartments have 24-hour visitation, 7 days per week. In all other undergraduate residences, guests are permitted Sunday through Thursday from 8 a.m. to 2 a.m. the following day, and 24-hour visitation from 8 a.m. Friday until 2 a.m. Monday. Weekend hours apply for Labor Day, October Break, and Martin Luther King Jr. Day. Under all circumstances, the privacy of your roommate takes priority over a guest.'},
#     {'section_title': 'Guests Overnight',
#      'text': "Overnight guests may stay no more than three consecutive nights. Two guests can stay in one room. A person's presence on a regular or continued basis without a formal contract is considered cohabitation and will not be permitted."},
#     {'section_title': 'Harassment',
#      'text': 'Purdue University maintains the campus free of sexual harassment and harassment on the basis of color, religion, sex, national origin, sexual orientation or other protected status. University Residences prohibits behavior that violates this policy and appropriate University authorities will be notified.'},
#     {'section_title': 'Hate Crimes',
#      'text': 'Hate crimes are acts that manifest evidence that the victim was intentionally selected because of their actual or perceived race, gender, religion, sexual orientation, ethnicity or disability and will be reported to the police.'},
#     {'section_title': 'Non-Compliance',
#      'text': 'Residents must comply with the directions of University officials (including resident assistants) acting in the performance of their duties.'},
#     {'section_title': 'Obscenity',
#      'text': 'Lewd, indecent or obscene conduct on University property or in connection with a University activity is prohibited.'},
#     {'section_title': 'Pets',
#      'text': 'Residents may only have small fish as pets.'},
#     {'section_title': 'Physical Abuse',
#      'text': 'Residents must refrain from any conduct that causes harm to another person.'},
#     {'section_title': 'Quiet and Courtesy Hours',
#      'text': 'Quiet Hours are Sunday through Thursday from 10 p.m. to 8 a.m., and Friday through Saturday from 12 a.m. to 10 a.m. During final examination periods, 24-hour quiet periods are in effect. Residents are expected to always demonstrate consideration and courtesy toward others.'},
#     {'section_title': 'Recreational Equipment — Items Prohibited',
#      'text': 'Items prohibited from University Residences buildings and grounds include: paintball guns, metal-tipped darts, juggling knives, battery or gasoline-motorized cycles, electric scooters, self-balancing scooters, and hoverboards. Bicycles, rollerblades, roller skates, and skateboards may not be ridden through doors, into the lobby, or down hallways.'},
#     {'section_title': 'ResNet',
#      'text': "ResNet bandwidth is a limited resource and users are required to act responsibly. Continued abuse of bandwidth or tampering with Wireless Access Points (WAPs) could result in permanent disconnection of ResNet service. Users are subject to Purdue IT's Acceptable Use Policy and may not broadcast a separate wireless signal in the residence hall."},
#     {'section_title': 'Room Appliances and Furnishings',
#      'text': 'Allowable cooking appliance use in rooms is limited to: coffee/tea makers with enclosed heating elements, portable microwave ovens (1000 watts or less), and portable refrigerators (UL approved, maximum 4.0 cu ft). Only one refrigerator and one microwave are permitted per room, and they must not share the same outlet. Appliance use in community kitchenettes cannot be left unattended. Entertainment equipment such as televisions, stereos, computers, and game consoles are permitted, but sound amplification and image projection that disrupts the community is prohibited. Students may not permanently alter walls, ceilings, floors, doors, or windows.'},
#     {'section_title': 'Security',
#      'text': 'All undergraduate residences except Hilltop Apartments are locked from 11 p.m. to 6 a.m. University ID is required for entrance after 11 p.m. Hawkins Hall is locked from 12 a.m. to 6 a.m. A locked door may not be propped open or used to allow entry.'},
#     {'section_title': 'Sex Offenses',
#      'text': "Sexual acts directed against another person forcibly and/or against that person's will, or where the victim is incapable of giving consent, or unlawful non-forcible sexual intercourse will be reported to the police and/or other University authorities as appropriate."},
#     {'section_title': 'Self-Care Policy',
#      'text': 'All residents are responsible for their own self care including appropriate personal hygiene, management of medical conditions or illnesses including mental health and/or disability-related personal needs.'},
#     {'section_title': 'Smoking/Vaping',
#      'text': 'Smoking and vaping are prohibited on the West Lafayette campus except in designated smoking areas. University Residences prohibits use of e-cigarettes (personal vaporizing instruments) in facilities the same as traditional tobacco products.'},
#     {'section_title': 'Solicitation',
#      'text': 'Residents may not use their rooms or ResNet connections for commercial purposes, including solicitation or sales. Salespersons may not solicit door to door. Delivery persons must make their transactions in the lobby.'},
#     {'section_title': 'Theft',
#      'text': 'Theft or attempted theft of, or unauthorized use or possession of property belonging to the University or another person associated with the University is not permitted.'},
#     {'section_title': 'Threatening/Endangering Behavior',
#      'text': 'Intimidation or any conduct that threatens or endangers the health or safety of another person or oneself is prohibited.'},
#     {'section_title': 'Unauthorized Access or Use',
#      'text': 'Residents are prohibited from unauthorized entry or access to, or unauthorized use or occupancy of any University Residence property including land, buildings, structures, telecommunications, computer or data processing equipment, programs, systems or software.'},
#     {'section_title': 'Vandalism',
#      'text': 'Causing damage to property of any kind belonging to the University or any other person associated with the University is prohibited.'},
#     {'section_title': 'Video Recording Policy',
#      'text': 'Residents are prohibited from making audio/video recordings or streaming of any person(s) or their personal property without consent where there is a reasonable expectation of privacy. Areas include but are not limited to showers, restrooms, bedrooms, and locker rooms.'},
#     {'section_title': 'Summary Exclusion from University Residences',
#      'text': 'A summary exclusion is an immediate action taken by the Director of Campus Living and Compliance or designee that prohibits a resident from entering any University Residence residential halls and Purdue Dining & Culinary locations. A summary exclusion can be issued when: physical facilities are used inconsistently, disruption of university programs occurs or will occur, interference with the educational mission exists, threats or behaviors pose a safety risk, or a specific facility policy is violated.'}]},
#   {'section_title': 'Room and Apartment Information',
#    'subsections': [{'section_title': 'General Information',
#      'text': 'Residents may not lease, sublease or reassign their room/apartment to another person. Extended beds are available in limited quantities on a first-come, first-serve basis for any resident 6\'4" or taller. Extended beds and lofts are not available in UR Boiler Apartments (URBA).'},
#     {'section_title': 'Items Provided by University Residences',
#      'text': 'University Residences provides: one bed per resident with mattress (standard 77" x 36" x 7"), safety bed rail for lofted or bunked beds, curtains or window blinds, smoke detector, trash can and blue recycling container, shower curtain, all utilities, internet access via wireless and Ethernet port, and cable television outlet and service and/or access to BoilerTV streaming service.'},
#     {'section_title': 'Appliances and Room Modifications',
#      'text': 'University Residence apartment-style housing with appropriate kitchen facilities does allow for food preparation using various appliances, but cooking cannot be left unattended. General modifications not allowed in any University Residence include drilling, sawing, painting, and use of screws, nails, or glue as attachment mechanisms. Temporary adhesive strips/hooks are allowed but limited to no more than 15 per room. Temporary mechanical alterations to windows, doors, locks, or HVAC controls are not permitted.'},
#     {'section_title': 'Door and Window Decorations',
#      'text': 'Only Door Decs are allowed on residence hall/apartment doors, limited to 2 per occupant. No items may be affixed or block the windows for fire safety purposes. Items can be placed on the sill. Doors cannot be wrapped in paper or other material. Posters and bulletin boards are not permitted on doors.'},
#     {'section_title': 'BoilerTV',
#      'text': 'University Residences operates its own cable TV system. All student rooms and apartments receive the service at no additional charge. Approximately 20 FM radio stations are also offered. Most residences have one cable connector in each room.'},
#     {'section_title': 'Computers',
#      'text': 'ResNet (Residential Networks) allows residents to connect personal devices to the campus network wirelessly via PAL3.0 or by Ethernet. ResNet bandwidth is a limited resource and users must act responsibly. Students assigned to UR Boiler Apartments will have high-speed Internet service provided by local providers.'},
#     {'section_title': 'Keys',
#      'text': 'Residents are responsible for keeping their room key at all times. Never give it to anyone. If a key is lost, report it immediately to the main office — a fee will be charged for replacement locks and keys. Keys are required to be turned in when moving out.'},
#     {'section_title': 'Linen',
#      'text': 'Residents are responsible for providing and laundering their own sheets, pillows, pillowcases and bedspreads.'},
#     {'section_title': 'Room Access',
#      'text': "Staff have the right to enter residents' rooms for cleaning, maintenance, to repair University property, or in emergencies and other situations involving health or safety concerns."}]},
#   {'section_title': 'Hall Facility Information',
#    'subsections': [{'section_title': 'Bulletin Boards',
#      'text': "Advertisements, posters, flyers, notices, signs, or banners must adhere to all University policies and state, local and federal laws. Promoting the use of alcohol and/or illegal substances is prohibited. All postings must be approved by the University Residences Director's Office."},
#     {'section_title': 'Housekeeping',
#      'text': 'University Residences service staff clean and maintain all common areas including lounges, hallways, study rooms and bathrooms. Students are responsible for the cleaning and care of their assigned private living space. Students living in apartment-style residences are responsible for all cleaning supplies including paper towels, toilet paper, and cleaning supplies.'},
#     {'section_title': 'Insurance',
#      'text': "The University does not carry insurance covering the loss, theft or damage of residents' personal effects. Residents should check their family's homeowner's insurance or obtain their own coverage at their own expense."},
#     {'section_title': 'Laundry and Vending',
#      'text': 'Each residence has its own laundry facilities with washers, dryers, soaking tubs, irons and ironing boards. Washers and dryers only accept payment from the CSCPay Mobile laundry app. Refunds for money lost in laundry machines can be requested through the app.'},
#     {'section_title': 'Lost and Found',
#      'text': "Each residence hall has a lost and found department located in the main office area. Items are normally held for a short time, then moved to the University's Central Lost and Found facility located in the Parking Facilities Office at Purdue West Shopping Plaza."},
#     {'section_title': 'Mail',
#      'text': 'Campus mail is free and is only for University business, not personal use. When mailing via the U.S. Postal Service, use your full return address. Do not include P.O. or Box in the return address. Use all capital or block letters and no punctuation. Cash should never be sent through the mail system.'},
#     {'section_title': 'Recycling',
#      'text': 'University Residences maintains a single-stream recycling program. Blue recycling containers are provided in each student room, with larger containers on each floor. Recyclable materials include paper, cardboard, newspaper, plastic, glass, and aluminum.'},
#     {'section_title': 'Repairs and Maintenance',
#      'text': 'Work orders can be submitted via the online Fix My Home website. For emergency maintenance, notify a Resident Assistant, Facilities staff, or the hall main office. There is no charge for routine repairs.'}]},
#   {'section_title': 'Student Identification Card',
#    'subsections': [{'section_title': 'PUID',
#      'text': "All incoming Purdue University students will be issued a Purdue Mobile ID as their first ID as part of Purdue's Mobile First Strategy. The Purdue ID functions as a key to many facilities and services on campus, including building access, library services, meals, Dining Dollars, Retail Dining Memberships, and Recreational Sports. The Purdue Mobile ID is not transferable and may only be used by the person to whom it is issued."}]},
#   {'section_title': 'Transportation',
#    'subsections': [{'section_title': 'Bus Service',
#      'text': 'SP+ routes loop through campus and have stops at or near all University Residences locations. Students ride free by showing their University ID cards.'},
#     {'section_title': 'Parking',
#      'text': "Regular parking permits are available for sophomores, juniors and seniors. Restricted parking permits are available to first year students only with approval from the resident's general manager and documentation of frequent/recurring medical visits off campus, classes off campus, or employment off campus. Non-resident visitors may obtain guest parking permits valid for up to three days."},
#     {'section_title': 'Bike Parking Rules and Securing Your Bicycle',
#      'text': "Bicycles may only be parked at approved bicycle racks and hoops and must be secured with a lock. Bike parking is not permitted on sidewalks, ADA accessible sidewalk railings, trees, fences, furniture, light poles, buildings, or anything other than a bike rack or hoop. Incorrectly parked bicycles are subject to removal and locks will be cut at the owner's expense."},
#     {'section_title': 'Walking',
#      'text': 'When walking on or off campus at night, go with a friend. The Purdue Student Security Patrol provides security escorts upon request on Thursday, Friday, and Saturday nights. To request an escort, call 49-4SAFE (494-7233). Emergency Telephone System (ETS) boxes painted bright yellow and illuminated with a blue light are located across campus.'}]},
#   {'section_title': 'Emergency Services',
#    'subsections': [{'section_title': 'General Information',
#      'text': 'If you consider a situation to be an emergency, then it is an emergency. Dial 911 — an on-campus phone will connect to Purdue Police/Fire; a cell phone will connect to the county emergency center. University Police and Fire Departments are staffed 24 hours a day, seven days a week, year-round.'},
#     {'section_title': 'Fire',
#      'text': 'Activate the alarm and evacuate the building. Call 911 from a safe location or use an emergency call box.'},
#     {'section_title': 'Medical Emergency',
#      'text': 'Call 911 or use emergency call box and report incident. Do not move the patient unless safety dictates. If trained, use pressure to stop bleeding and provide basic life support as needed.'},
#     {'section_title': 'Tornado',
#      'text': 'Avoid automobiles and open areas. Move to a basement or corridor. Stay away from windows. Do not call 911 unless you require emergency assistance.'},
#     {'section_title': 'Crime and Violent Behavior',
#      'text': 'Protect yourself first, then call 911. Give your name and location and inform the dispatcher the incident is in progress.'},
#     {'section_title': 'Reporting Sexual Crimes',
#      'text': 'Victims of sexual assault or other sexual crimes can receive assistance by contacting the Purdue University Police Department. For confidential assistance, visit CAPS or CARE. Reporting options and remedial measures are also available through the Office of Institutional Equity.'},
#     {'section_title': 'Psychological Crisis',
#      'text': 'If the situation becomes violent or life threatening, call 911. Other contacts include Counseling and Psychological Services at 494-7707, Employee Assistance Program at 494-7707, and Crisis Center at 742-0244.'},
#     {'section_title': 'Domestic Violence',
#      'text': 'Domestic violence is a pattern of coercive behaviors in which one person attempts to control another through threats or the actual use of physical violence, sexual assault, intimidation, verbal, emotional, or psychological abuse. Help is available through Counseling and Psychological Services (494-6995), Dean of Students (494-8698), International Student and Scholars (494-5770), and Purdue University Police Department (494-8221).'},
#     {'section_title': 'Bomb Threats',
#      'text': 'Call 911 or use an emergency call box and report the incident. If a suspicious object is observed: do not touch it and evacuate the area.'},
#     {'section_title': 'Explosion',
#      'text': 'Take cover, call 911, and assist the injured.'},
#     {'section_title': 'Hazardous Material Spill/Release',
#      'text': 'Call 911 or use an emergency call box and report incident. Secure the area, assist the injured, and evacuate if necessary.'},
#     {'section_title': 'Shelter in Place',
#      'text': 'Stay inside a building. Seek inside shelter if outside. Seal off openings to your room if possible.'},
#     {'section_title': 'Earthquake',
#      'text': 'Take cover. Call 911 or use an emergency call box if emergency assistance is necessary. Evacuate if alarm sounds or if told to do so by emergency personnel.'},
#     {'section_title': 'Utility Failure',
#      'text': 'Remain calm. Do not call the University Police Department for information concerning utility failures unless you have an emergency. Call the Community Center front desk at 765-494-2090. If you discover a gas leak, call the University Police Department at (765) 494-8221. Call 911 if you are injured or require emergency assistance.'}]}]}

# %%
import json

with open("../data/rag_mock_data.json") as f:
    raw_docs = json.load(f)

def flatten_policy_json(raw_docs):
    flat = []

    for doc in raw_docs:
        doc_id = doc.get("document_id")
        doc_title = doc.get("title")
        url = doc.get("url")
        domain = doc.get("domain")
        effective_date = doc.get("effective_date")

        for sec in doc.get("sections", []):
            sec_title = sec.get("section_title")

            # Case 1: section has direct text
            if "text" in sec and sec["text"]:
                flat.append({
                    "doc_id": doc_id,
                    "doc_title": doc_title,
                    "url": url,
                    "domain": domain,
                    "effective_date": effective_date,
                    "section_title": sec_title,
                    "subsection_title": None,
                    "text": sec["text"],
                })

            # Case 2: section has subsections
            for sub in sec.get("subsections", []):
                sub_title = sub.get("section_title")
                sub_text = sub.get("text")
                if sub_text:
                    flat.append({
                        "doc_id": doc_id,
                        "doc_title": doc_title,
                        "url": url,
                        "domain": domain,
                        "effective_date": effective_date,
                        "section_title": sec_title,
                        "subsection_title": sub_title,
                        "text": sub_text,
                    })

    return flat

docs = flatten_policy_json(raw_docs)
print("Flat entries:", len(docs))
docs[0]
# Out:
# Flat entries: 105
# {'doc_id': 'housing_policy_2025',
#  'doc_title': 'University Residences Guidelines and Policies',
#  'url': 'https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html',
#  'domain': 'housing',
#  'effective_date': '2025-12-15',
#  'section_title': 'Emergency Procedures',
#  'subsection_title': 'Accidents',
#  'text': 'Contact the nearest staff member or the main office for assistance. Staff will arrange ambulance transportation and other needed help. Dial 9-1-1 from any campus telephone for immediate contact with the Purdue Police.'}

# %%
def chunk_text(text, max_words=140, overlap=30):
    words = text.split()
    chunks = []
    start = 0
    while start < len(words):
        end = start + max_words
        chunks.append(" ".join(words[start:end]))
        start += max_words - overlap
    return chunks

all_chunks = []

for doc in docs:
    chunks = chunk_text(doc["text"])
    subsection = doc["subsection_title"]

    # stable id prefix
    sec_key = doc["section_title"] if subsection is None else f"{doc['section_title']}::{subsection}"

    for i, chunk in enumerate(chunks):
        all_chunks.append({
            "id": f"{doc['doc_id']}::{sec_key}::{i}",
            "text": chunk,
            "metadata": {
                "doc_id": doc["doc_id"],
                "doc_title": doc["doc_title"],
                "url": doc["url"],
                "domain": doc["domain"],
                "effective_date": doc["effective_date"],
                "section_title": doc["section_title"],
                "subsection_title": doc["subsection_title"],
                "chunk_index": i,
            }
        })

print("Total chunks:", len(all_chunks))
all_chunks[0]
# Out:
# Total chunks: 106
# {'id': 'housing_policy_2025::Emergency Procedures::Accidents::0',
#  'text': 'Contact the nearest staff member or the main office for assistance. Staff will arrange ambulance transportation and other needed help. Dial 9-1-1 from any campus telephone for immediate contact with the Purdue Police.',
#  'metadata': {'doc_id': 'housing_policy_2025',
#   'doc_title': 'University Residences Guidelines and Policies',
#   'url': 'https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html',
#   'domain': 'housing',
#   'effective_date': '2025-12-15',
#   'section_title': 'Emergency Procedures',
#   'subsection_title': 'Accidents',
#   'chunk_index': 0}}

# %%
import os
from dotenv import load_dotenv
from pinecone import Pinecone, ServerlessSpec

load_dotenv()

pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
index_name = os.getenv("PINECONE_INDEX_NAME")

existing = [i["name"] for i in pc.list_indexes()]
if index_name not in existing:
    pc.create_index(
        name=index_name,
        dimension=384,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )

index = pc.Index(index_name)
print("Index ready:", index_name)
# Out:
# Index ready: boilercheck-rag

# %%
# Vector embedding + upsert block (Pinecone-safe metadata)
import os
import time
import hashlib
from dotenv import load_dotenv
from pinecone import Pinecone, ServerlessSpec
from sentence_transformers import SentenceTransformer

load_dotenv()

INDEX_NAME = os.getenv("PINECONE_INDEX_NAME", "purdue-policy-index-v3")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
if not PINECONE_API_KEY:
    raise RuntimeError("Missing PINECONE_API_KEY in .env")

EMBED_MODEL_NAME = "all-MiniLM-L6-v2"
DIM = 384
REGION = "us-east-1"
BATCH_SIZE = 100

def make_chunk_id(doc_id: str, section_title: str, subsection_title: str, chunk_index: int) -> str:
    # subsection_title should already be a string ("" if missing)
    key = f"{doc_id}|{section_title}|{subsection_title}|{chunk_index}"
    h = hashlib.sha1(key.encode("utf-8")).hexdigest()
    return f"{doc_id}__{h}"

def batched(lst, batch_size):
    for i in range(0, len(lst), batch_size):
        yield lst[i:i + batch_size]

if "all_chunks" not in globals():
    raise RuntimeError("Expected `all_chunks` to exist. Run your chunking cell first.")

print("Chunks to embed:", len(all_chunks))

# Init Pinecone + create index if needed
pc = Pinecone(api_key=PINECONE_API_KEY)

existing = [i["name"] for i in pc.list_indexes()]
if INDEX_NAME not in existing:
    pc.create_index(
        name=INDEX_NAME,
        dimension=DIM,
        metric="cosine",
        spec=ServerlessSpec(cloud="aws", region=REGION),
    )
    print("Created index:", INDEX_NAME)

index = pc.Index(INDEX_NAME)
print("Index ready:", INDEX_NAME)

# Load embedding model on CPU
model = SentenceTransformer(EMBED_MODEL_NAME, device="cpu")
print("Embedding model loaded:", EMBED_MODEL_NAME)

total = 0
t0 = time.time()

for batch in batched(all_chunks, BATCH_SIZE):
    vectors = []

    for c in batch:
        md = dict(c["metadata"])  # copy

        # Ensure Pinecone-safe metadata types (no None/null)
        md["subsection_title"] = md.get("subsection_title") or ""   # null -> ""
        md["section_title"] = md.get("section_title") or ""         # defensive
        md["doc_id"] = md.get("doc_id") or ""
        md["doc_title"] = md.get("doc_title") or ""
        md["url"] = md.get("url") or ""
        md["domain"] = md.get("domain") or ""
        md["effective_date"] = md.get("effective_date") or ""

        # Ensure chunk_index is a number
        md["chunk_index"] = int(md.get("chunk_index", 0))

        # Build stable ASCII id
        vec_id = make_chunk_id(md["doc_id"], md["section_title"], md["subsection_title"], md["chunk_index"])

        emb = model.encode(c["text"]).tolist()

        # Add a readable key for citations
        source_key = md["section_title"] if md["subsection_title"] == "" else f"{md['section_title']} > {md['subsection_title']}"

        vectors.append({
            "id": vec_id,
            "values": emb,
            "metadata": {
                **md,
                "text": c["text"],          # string OK
                "source_key": source_key,   # string OK
            },
        })

    index.upsert(vectors=vectors)
    total += len(vectors)
    print(f"Upserted so far: {total} (elapsed {time.time() - t0:.1f}s)")

print("Done. Total upserted:", total)
print("Index stats:", index.describe_index_stats())
# Out:
# Chunks to embed: 106
# Index ready: boilercheck-rag
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Embedding model loaded: all-MiniLM-L6-v2
# Upserted so far: 100 (elapsed 1.7s)
# Upserted so far: 106 (elapsed 2.0s)
# Done. Total upserted: 106
# Index stats: {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '185',
#                                     'content-type': 'application/json',
#                                     'date': 'Tue, 24 Feb 2026 00:35:18 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '38',
#                                     'x-pinecone-request-latency-ms': '37',
#                                     'x-pinecone-response-duration-ms': '48'}},
#  'dimension': 384,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 106}},
#  'storageFullness': 0.0,
#  'total_vector_count': 106,
#  'vector_type': 'dense'}

# %%
query = "Are portable refrigerators allowed in University Residences rooms?"

q_emb = model.encode(query).tolist()
res = index.query(vector=q_emb, top_k=5, include_metadata=True)

for i, m in enumerate(res["matches"], start=1):
    md = m["metadata"]
    print("\n---", i)
    print("Score:", round(m["score"], 4))
    print("Source:", md.get("doc_title", ""))
    print("Where:", md.get("source_key", ""))
    print("Text:", md.get("text", "")[:350], "...")
    print("URL:", md.get("url", ""))
# Out:
# --- 1
# Score: 0.715
# Source: University Residences Guidelines and Policies
# Where: Safety > Items Prohibited
# Text: Items prohibited from University Residences buildings and grounds due to safety or fire hazard concerns include but are not limited to: electric/battery or gasoline motorized cycles, scooters, hoverboards or similar equipment; electric blankets or electric bed warmers of any kind; grow lights; halogen lamps; soldering tools; sun lamps; paintball gu ...
# URL: https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html
#
# --- 2
# Score: 0.6791
# Source: University Residences Guidelines and Policies
# Where: Student Conduct Policies > Room Appliances and Furnishings
# Text: Allowable cooking appliance use in rooms is limited to: coffee/tea makers with enclosed heating elements, portable microwave ovens (1000 watts or less), and portable refrigerators (UL approved, maximum 4.0 cu ft). Only one refrigerator and one microwave are permitted per room, and they must not share the same outlet. Appliance use in community kitc ...
# URL: https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html
#
# --- 3
# Score: 0.6228
# Source: University Residences Guidelines and Policies
# Where: Room and Apartment Information > Appliances and Room Modifications
# Text: University Residence apartment-style housing with appropriate kitchen facilities does allow for food preparation using various appliances, but cooking cannot be left unattended. General modifications not allowed in any University Residence include drilling, sawing, painting, and use of screws, nails, or glue as attachment mechanisms. Temporary adhe ...
# URL: https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html
#
# --- 4
# Score: 0.5638
# Source: University Residences Guidelines and Policies
# Where: Student Conduct Policies > Recreational Equipment — Items Prohibited
# Text: Items prohibited from University Residences buildings and grounds include: paintball guns, metal-tipped darts, juggling knives, battery or gasoline-motorized cycles, electric scooters, self-balancing scooters, and hoverboards. Bicycles, rollerblades, roller skates, and skateboards may not be ridden through doors, into the lobby, or down hallways. ...
# URL: https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html
#
# --- 5
# Score: 0.5175
# Source: University Residences Guidelines and Policies
# Where: Room and Apartment Information > Room Access
# Text: Staff have the right to enter residents' rooms for cleaning, maintenance, to repair University property, or in emergencies and other situations involving health or safety concerns. ...
# URL: https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    default_headers={
        "HTTP-Referer": "http://localhost:3000",  # any URL is fine
        "X-Title": "Purdue Policy RAG MVP",
    },
)

def format_context(matches, max_chars=900):
    blocks = []
    for i, m in enumerate(matches, start=1):
        md = m["metadata"]

        section_path = md["section_title"]
        if md.get("subsection_title"):
            section_path += f" > {md['subsection_title']}"

        text = md.get("text", "")
        if len(text) > max_chars:
            text = text[:max_chars] + "..."

        blocks.append(
            f"""
SOURCE {i}
Title: {md.get('doc_title','')}
Section: {section_path}
URL: {md.get('url','')}
CitationID: [{md.get('url','')}#{section_path}]

{text}
"""
        )
    return "\n".join(blocks)

def kimi_rag_answer(query, top_k=6):
    q_emb = model.encode(query).tolist()
    res = index.query(vector=q_emb, top_k=top_k, include_metadata=True)

    context = format_context(res["matches"])

    prompt = f"""
You are a Purdue policy assistant.

Use ONLY the provided sources.

CITATION RULES:
- Cite using the CitationID provided in each source.
- Always include the full site citation like:
  [https://...#Section Name]

If the answer is not in the sources, say you cannot confirm.

SOURCES:
{context}

QUESTION:
{query}
"""

    response = client.chat.completions.create(
    model="openrouter/free",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.2,
    )

    print(response.choices[0].message.content)

# test
kimi_rag_answer("Are portable refrigerators allowed in University Residences rooms?")
# Out:
# Yes, portable refrigerators (UL approved, maximum 4.0 cu ft) are allowed in University Residences rooms [https://www.housing.purdue.edu/campus-living/resources/guidelines-policies/ur-guidelines.html#Student Conduct Policies > Room Appliances and Furnishings].
